# %% [markdown]
# # Módulo 5 - Funções
#
# ## Aulas 5.2 - Funções Customizadas e 5.4 Funções ```lambda```

# %% [markdown]
# ### Q1.
#
# - Sabendo que o código a seguir calcula o fatorial de n, escreva uma função chamada ```fatorial()``` que recebe um inteiro ```n``` como parâmetro e retorna o resultado do fatorial de ```n```.
# - No programa principal, peça ao usuário o valor de ```n```, chame a sua função e imprima o retorno.
#
# ```python
# fat = 1
# for i in range(1, n+1):
#     fat *= i
# ```

# %%
def fatorial(valor):
    #corpo da função
    fat = 1
    for i in range(1, valor+1):
        fat *= i
    return fat

# %%
for n in range(1,6):
  meu_fatorial = fatorial(n)
  print(f"{n}! é {meu_fatorial}")
# Out:
# Digite o valor de n:  20
# 1! é 1
# 2! é 2
# 3! é 6
# 4! é 24
# 5! é 120

# %% [markdown]
# ### Q2.
#
# - Escreva uma função em Python chamada ```soma_quadrados``` que recebe dois números como parâmetros e retorna a soma dos seus quadrados.
# - No programa principal solicite ao usuário que insira dois números e utilize a função para exibir a soma dos quadrados.

# %%
def soma_quadrados(a, b):
    """Retorna a soma dos quadrados de dois números."""
    return a**2 + b**2

# %%
# Programa principal
if __name__ == "__main__":
    num1 = float(input("Digite o primeiro número: "))
    num2 = float(input("Digite o segundo número: "))
    resultado = soma_quadrados(num1, num2)
    print(f"A soma dos quadrados de {num1} e {num2} é {resultado}.")
# Out:
# Digite o primeiro número: 1
# Digite o segundo número: 5
# A soma dos quadrados de 1.0 e 5.0 é 26.0.

# %% [markdown]
# ### Q3.
#
# - Crie uma função em Python chamada ```soma_digitos``` que recebe um número inteiro como parâmetro e retorna a soma dos seus dígitos. Por exemplo, para o número 123, a função deve retornar 6, $(1 + 2 + 3)$.
#     - O desafio aqui é separar os dígitos de um número inteiro usando operações aritméticas <br> <br>
#
# - No programa principal solicite ao usuário que insira um número e utilize a função ```soma_digitos``` para calcular e exibir a soma dos seus dígitos.

# %%
def soma_quadrados(a, b):
    """Retorna a soma dos quadrados de dois números."""
    return a**2 + b**2

def soma_digitos(n):
    """Retorna a soma dos dígitos de um número inteiro."""
    soma = 0
    while n > 0:
        soma += n % 10  # Obtém o último dígito
        n //= 10  # Remove o último dígito
    return soma

# %%
# Programa principal
if __name__ == "__main__":
    num1 = float(input("Digite o primeiro número: "))
    num2 = float(input("Digite o segundo número: "))
    resultado = soma_quadrados(num1, num2)
    print(f"A soma dos quadrados de {num1} e {num2} é {resultado}.")

    num = int(input("Digite um número inteiro: "))
    resultado_digitos = soma_digitos(num)
    print(f"A soma dos dígitos de {num} é {resultado_digitos}.")
# Out:
# Digite o primeiro número: 56
# Digite o segundo número: 25
# A soma dos quadrados de 56.0 e 25.0 é 3761.0.
# Digite um número inteiro: 20
# A soma dos dígitos de 20 é 2.

# %% [markdown]
# ### Q4.
#
# - Crie a função ```inverteValor()``` que recebe um inteiro de qualquer tamanho e retorna esse valor invertido usando apenas operações aritméticas
# - Crie a função ```verificaInverso()``` que recebe o valor original e o valor invertido e retorna verdadeiro se ambos forem igualmente par ou igualmente ímpar. Retorne falso caso contrário.
# - No programa principal, peça um valor do usuário e imprima o retorno de ambas as funções.

# %%
def inverteValor(n):
    """Inverte um número inteiro usando apenas operações aritméticas."""
    invertido = 0
    while n > 0:
        invertido = invertido * 10 + n % 10  # Adiciona o último dígito ao número invertido
        n //= 10  # Remove o último dígito do número original
    return invertido

def verificaInverso(original, invertido):
    """Verifica se ambos os números são igualmente pares ou ímpares."""
    return (original % 2) == (invertido % 2)

# %%
# Programa principal
try:
    numero = int(input("Digite um número inteiro positivo: "))
    if numero < 0:
        print("Por favor, digite um número positivo.")
    else:
        numero_invertido = inverteValor(numero)
        print(f"Número invertido: {numero_invertido}")
        print(f"Os números são igualmente pares ou ímpares? {verificaInverso(numero, numero_invertido)}")
except ValueError:
    print("Entrada inválida! Digite um número inteiro válido.")
# Out:
# Digite um número inteiro positivo: 20
# Número invertido: 2
# Os números são igualmente pares ou ímpares? True

# %% [markdown]
# ### Q5.
#
# Você está desenvolvendo um programa para auxiliar em cálculos de geometria básica. Crie as seguintes funções:
# - A função ```calcula_perimetro_triangulo()``` que recebe três inteiros correspondentes aos lados de um triângulo e retorna o perímetro do triângulo, ou seja, a soma dos seus lados.
# - A função ```calcula_perimetro_circulo()``` que recebe um inteiro referente ao raio do círculo e retorna o perímetro do círculo, dado por $2 \pi r$. Use a constante $\pi$ da biblioteca ```math```.
# - A função ```calcula_perimetro_retangulo()``` que possui um parâmetro obrigatório ```lado1``` e um opcional ```lado2```, ambos inteiros. Se o valor opcional não for fornecido, significa que se trata de um quadrado. Sua função deve calcular e retornar o perímetro do retângulo, ou seja, a soma de seus lados.
#     - Para o quadrado, é dado por $4 \times lado1$
#     - Para o retângulo é dado por $2 \times lado1 + 2 \times lado2$
#
# - No programa principal apresente um menu com as opções disponíveis do seu sistema e uma quarta opção ```Sair```. Solicite ao usuário a opção desejada, solicite as entradas correspondentes à opção escolhida, invoque a respective função e apresente o seu retorno. Seu programa deve retornar ao menu até que o usuário escolha a opção ```Sair```
#
# Exemplo de interação:
# ```
# 1 - Calcular perímetro triângulo
# 2 - Calcular perímetro círculo
# 3 - Calcular perímetro retângulo
# 4 - Sair
#
# Opção: 1
# Digite os três lados do triângulo:
# 3
# 4
# 5
# O perímetro é: 12
#
# 1 - Calcular perímetro triângulo
# 2 - Calcular perímetro círculo
# 3 - Calcular perímetro retângulo
# 4 - Sair
#
# Opção: 3
# Informe os dois lados do retângulo. Se for um quadrado, digite 0 para o segundo valor:
# 5
# 0
# O perímetro é: 20
#
# 1 - Calcular perímetro triângulo
# 2 - Calcular perímetro círculo
# 3 - Calcular perímetro retângulo
# 4 - Sair
#
# Opção: 4
# ```

# %%
import math

def soma_quadrados(a, b):
    """Retorna a soma dos quadrados de dois números."""
    return a**2 + b**2

def soma_digitos(n):
    """Retorna a soma dos dígitos de um número inteiro."""
    soma = 0
    while n > 0:
        soma += n % 10  # Obtém o último dígito
        n //= 10  # Remove o último dígito
    return soma

def calcula_perimetro_triangulo(a, b, c):
    """Retorna o perímetro de um triângulo."""
    return a + b + c

def calcula_perimetro_circulo(r):
    """Retorna o perímetro de um círculo."""
    return 2 * math.pi * r

def calcula_perimetro_retangulo(lado1, lado2=None):
    """Retorna o perímetro de um retângulo ou quadrado."""
    if lado2 is None or lado2 == 0:
        return 4 * lado1
    return 2 * (lado1 + lado2)

# %%
# Programa principal
if __name__ == "__main__":
    while True:
        print("\n1 - Calcular perímetro triângulo")
        print("2 - Calcular perímetro círculo")
        print("3 - Calcular perímetro retângulo")
        print("4 - Sair")
        opcao = int(input("\nOpção: "))

        if opcao == 1:
            a = int(input("Digite o primeiro lado do triângulo: "))
            b = int(input("Digite o segundo lado do triângulo: "))
            c = int(input("Digite o terceiro lado do triângulo: "))
            print(f"O perímetro é: {calcula_perimetro_triangulo(a, b, c)}")

        elif opcao == 2:
            r = int(input("Digite o raio do círculo: "))
            print(f"O perímetro é: {calcula_perimetro_circulo(r):.2f}")

        elif opcao == 3:
            lado1 = int(input("Informe o primeiro lado do retângulo: "))
            lado2 = int(input("Informe o segundo lado do retângulo (ou 0 para quadrado): "))
            print(f"O perímetro é: {calcula_perimetro_retangulo(lado1, lado2)}")

        elif opcao == 4:
            print("Saindo...")
            break
        else:
            print("Opção inválida. Tente novamente.")
# Out:
# 1 - Calcular perímetro triângulo
# 2 - Calcular perímetro círculo
# 3 - Calcular perímetro retângulo
# 4 - Sair
#
# Opção: 3
# Informe o primeiro lado do retângulo: 12
# Informe o segundo lado do retângulo (ou 0 para quadrado): 58
# O perímetro é: 140
#
# 1 - Calcular perímetro triângulo
# 2 - Calcular perímetro círculo
# 3 - Calcular perímetro retângulo
# 4 - Sair
#
# Opção: 4
# Saindo...

# %% [markdown]
# ## Funções ```lambda```

# %% [markdown]
# ### Q6.
#
# Crie uma função lambda para verificar se um número é par ou ímpar. Em seguida, solicite ao usuário um número indefinidos de valores (até que o usuário digite 0). Para cada valor de entrada, informe se é par ou ímpar.
#
# Exemplo de interação:
# ```
# Digite os valores que deseja verificar a paridade (digite 0 para finalizar a entrada de dados):
# 3
# ímpar
# 8
# par
# 12
# par
# 5
# ímpar
# 7ímpar
# ```

# %%
# Função lambda para verificar se um número é par ou ímpar
par_ou_impar = lambda x: "par" if x % 2 == 0 else "ímpar"

print("Digite os valores que deseja verificar a paridade (digite 0 para finalizar a entrada de dados):")

while True:
    try:
        num = int(input())  # Solicita um número do usuário
        if num == 0:
            break  # Sai do loop se o número for 0
        print(par_ou_impar(num))  # Exibe se o número é par ou ímpar
    except ValueError:
        print("Por favor, digite um número inteiro válido.")
# Out:
# Digite os valores que deseja verificar a paridade (digite 0 para finalizar a entrada de dados):
# 2
# par
# 6
# par
# 5
# ímpar
# 0

# %% [markdown]
# ### Q7.
#
# Escreva um programa que pergunte ao usuário qual operação ele deseja: maior ou menor.
# Em seguida leia uma quantidade indefinida de valores do usuário, até que o usuário digite o valor zero.
# Apresente ao final o maior ou menor dos valores digitados de acordo com a escolha do usuário.
#
# **Sua solução deve incluir pelo menos uma função ```lambda```**
#
# Exemplo de interação:
# ```
# Opções: (1) maior ou (2) menor?
# Opção: 1
#
# Digite os valores de entrada. Digite 0 para finalizar a entrada de valores.
# 4
# 12
# 15
# 1
# 0
#
# O maior valor é: 15
# ```

# %%
# Definição das funções lambda para encontrar o maior ou menor valor
maior_valor = lambda lista: max(lista) if lista else None
menor_valor = lambda lista: min(lista) if lista else None

# Pergunta ao usuário qual operação deseja realizar
opcao = input("Opções: (1) maior ou (2) menor?\nOpção: ")

# Lista para armazenar os números fornecidos pelo usuário
valores = []

print("\nDigite os valores de entrada. Digite 0 para finalizar a entrada de valores.")
while True:
    try:
        num = int(input())  # Lê um número do usuário
        if num == 0:
            break  # Encerra a entrada de valores se for digitado 0
        valores.append(num)
    except ValueError:
        print("Por favor, digite um número inteiro válido.")

# Verifica a opção escolhida e exibe o resultado
if valores:  # Garante que a lista não está vazia
    if opcao == "1":
        print(f"\nO maior valor é: {maior_valor(valores)}")
    elif opcao == "2":
        print(f"\nO menor valor é: {menor_valor(valores)}")
    else:
        print("\nOpção inválida. Reinicie o programa e escolha 1 ou 2.")
else:
    print("\nNenhum valor válido foi inserido.")
# Out:
# Opções: (1) maior ou (2) menor?
# Opção: 5
#
# Digite os valores de entrada. Digite 0 para finalizar a entrada de valores.
# 25
# 30
# 6
# 14
# 0
#
# Opção inválida. Reinicie o programa e escolha 1 ou 2.
